# %%
import os
import numpy as np
import nibabel as nib
from nibabel.processing import resample_from_to
from nibabel.orientations import aff2axcodes
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

def ensure_folder_exists(folder_path):
    """Create folder if it doesn't exist"""
    if not os.path.exists(folder_path):
        os.makedirs(folder_path, exist_ok=True)
    return folder_path

def load_and_process_nifti(file_path):
    """Load and preprocess NIFTI file with proper orientation"""
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")
    
    img = nib.load(file_path)
    img = nib.as_closest_canonical(img)
    print(f"Image orientation: {aff2axcodes(img.affine)}")
    
    data = img.get_fdata()
    data = np.transpose(data, (1, 0, 2))
    data = np.rot90(data, k=2, axes=(0, 1))
    
    return img, data

def align_mask_to_base(base_img, mask_img):
    """Align mask to base image using nibabel's resampling"""
    base_ras = nib.as_closest_canonical(base_img)
    mask_ras = nib.as_closest_canonical(mask_img)
    mask_resampled = resample_from_to(mask_ras, base_ras)
    
    mask_data = mask_resampled.get_fdata()
    mask_data = np.transpose(mask_data, (1, 0, 2))
    mask_data = np.rot90(mask_data, k=2, axes=(0, 1))
    binary_mask = (mask_data > 0.5).astype(np.uint8)
    
    return binary_mask

def visualize_slice(image_data, masks, output_path, subject_id, phase_type):
    """Create a visualization of a middle slice with mask overlays"""
    middle_slice_idx = image_data.shape[2] // 2
    slice_data = image_data[:, :, middle_slice_idx]
    
    plt.figure(figsize=(12, 8))
    plt.imshow(slice_data, cmap='gray')
    
    colors = ['red', 'blue', 'green', 'yellow']
    
    for (name, mask_data), color in zip(masks.items(), colors):
        mask_slice = mask_data[:, :, middle_slice_idx]
        plt.imshow(mask_slice, alpha=0.3, cmap=LinearSegmentedColormap.from_list('custom', ['none', color]))
    
    plt.title(f"{subject_id} - {phase_type} (Slice {middle_slice_idx})")
    plt.savefig(output_path)
    plt.close()
    print(f"Saved visualization to: {output_path}")

def create_phase_image(water_path, fat_path, output_dir, sbt_number, mask_paths, is_in_phase):
    """Create In Phase or Out Phase image from Water and Fat"""
    try:
        phase_type = "InPhase" if is_in_phase else "OutPhase"
        print(f"\nProcessing SBT{sbt_number:03d} with {phase_type}")
        
        # Load Water and Fat images
        water_img, water_data = load_and_process_nifti(water_path)
        fat_img, fat_data = load_and_process_nifti(fat_path)
        
        print(f"Water data shape: {water_data.shape}")
        print(f"Fat data shape: {fat_data.shape}")
        
        # Calculate phase data
        if is_in_phase:
            phase_data = water_data + fat_data
        else:
            phase_data = water_data - fat_data
        
        # Normalize to 16-bit range
        phase_data = ((phase_data - phase_data.min()) / 
                     (phase_data.max() - phase_data.min()) * 65535).astype(np.uint16)
        
        # Create output directory (no phase type in folder name)
        subject_id = f"SBT{sbt_number:03d}"
        subject_dir = ensure_folder_exists(os.path.join(output_dir, subject_id))
        
        # Save phase image
        phase_path = os.path.join(subject_dir, f"{subject_id}_images.nii")
        phase_img = nib.Nifti1Image(phase_data, water_img.affine)
        nib.save(phase_img, phase_path)
        print(f"Saved {phase_type} image: {phase_path}")
        
        # Process masks
        processed_masks = {}
        for name, mask_path in mask_paths.items():
            print(f"\nProcessing mask: {name}")
            mask_img = nib.load(mask_path)
            aligned_mask = align_mask_to_base(water_img, mask_img)
            
            # Save mask
            mask_output_name = f"{subject_id}_{name}_II.nii"
            mask_output_path = os.path.join(subject_dir, mask_output_name)
            mask_img_out = nib.Nifti1Image(aligned_mask, water_img.affine)
            nib.save(mask_img_out, mask_output_path)
            print(f"Saved mask to: {mask_output_path}")
            
            processed_masks[name] = aligned_mask
        
        # Save visualization
        vis_output_path = os.path.join(subject_dir, f"{subject_id}_visualization.png")
        visualize_slice(phase_data, processed_masks, vis_output_path, subject_id, phase_type)
        
        return True
        
    except Exception as e:
        print(f"Error processing SBT{sbt_number:03d}: {str(e)}")
        return False

def process_subject(subject_id, base_dir, start_sbt_number):
    """Process a single subject, creating two SBT folders"""
    try:
        # Construct file paths
        subject_dir = os.path.join(base_dir, subject_id)
        water_path = os.path.join(subject_dir, f"{subject_id}_IDEALWater.nii")
        fat_path = os.path.join(subject_dir, f"{subject_id}_IDEALFat.nii")
        
        # Define mask paths
        mask_paths = {
            "L_ES": os.path.join(subject_dir, f"{subject_id}_L_ES_MASK.nii"),
            "L_Mult": os.path.join(subject_dir, f"{subject_id}_L_Multifidus_MASK.nii"),
            "R_ES": os.path.join(subject_dir, f"{subject_id}_R_ES_MASK.nii"),
            "R_Mult": os.path.join(subject_dir, f"{subject_id}_R_Multifidus_MASK.nii")
        }
        
        # Verify all files exist
        all_paths = [water_path, fat_path] + list(mask_paths.values())
        for path in all_paths:
            if not os.path.exists(path):
                print(f"Warning: File not found: {path}")
                return False
        
        processed_dir = "/Volumes/advent/processed_data"
        
        # First SBT number gets Out Phase
        success_out = create_phase_image(water_path, fat_path, processed_dir, 
                                       start_sbt_number, mask_paths, False)
        
        # Second SBT number gets In Phase
        success_in = create_phase_image(water_path, fat_path, processed_dir, 
                                      start_sbt_number + 1, mask_paths, True)
        
        return success_out and success_in
        
    except Exception as e:
        print(f"Error processing subject {subject_id}: {str(e)}")
        return False

def test_single_subject(subject_id, base_dir, start_sbt_number):
    """Test the processing pipeline on a single subject"""
    print(f"\n=== Testing processing for {subject_id} ===")
    print(f"Will create SBT{start_sbt_number:03d} (Out Phase) and SBT{start_sbt_number+1:03d} (In Phase)")
    
    try:
        success = process_subject(subject_id, base_dir, start_sbt_number)
        if success:
            print("\nProcessing successful! Created folders:")
            print(f"SBT{start_sbt_number:03d} - Out Phase")
            print(f"SBT{start_sbt_number+1:03d} - In Phase")
        else:
            print("\nProcessing failed. Check the error messages above.")
    except Exception as e:
        print(f"\nError during testing: {str(e)}")

def main():
    """Process all subjects"""
    base_dir = "/Volumes/advent/research/MRI/Marines/Analysis2"
    
    # Get all subject directories
    subject_dirs = sorted([d for d in os.listdir(base_dir) 
                         if os.path.isdir(os.path.join(base_dir, d))
                         and d.startswith("LS")])
    
    current_sbt = 94  # Start with SBT094
    for subject_id in subject_dirs:
        print(f"\nProcessing {subject_id} -> SBT{current_sbt:03d}/SBT{current_sbt+1:03d}")
        success = process_subject(subject_id, base_dir, current_sbt)
        if success:
            print(f"Successfully processed {subject_id}")
            current_sbt += 2  # Increment by 2 for next subject
        else:
            print(f"Failed to process {subject_id}")

if __name__ == "__main__":
    # Test on a single subject
    # Uncomment the next line to test a single subject:
    # test_single_subject("LS011", "/Volumes/advent/research/MRI/Marines/Analysis2", 94)
    
    # Comment out the next line when testing single subject:
    main()
# Out:
# Processing LS002 -> SBT094/SBT095
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS002/LS002_L_ES_MASK.nii
# Failed to process LS002
#
# Processing LS003 -> SBT094/SBT095
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS003/LS003_L_ES_MASK.nii
# Failed to process LS003
#
# Processing LS004 -> SBT094/SBT095
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS004/LS004_L_ES_MASK.nii
# Failed to process LS004
#
# Processing LS006 -> SBT094/SBT095
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS006/LS006_L_ES_MASK.nii
# Failed to process LS006
#
# Processing LS007 -> SBT094/SBT095
#
# Processing SBT094 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT094/SBT094_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT094/SBT094_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT094/SBT094_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT094/SBT094_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT094/SBT094_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT094/SBT094_visualization.png
#
# Processing SBT095 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT095/SBT095_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT095/SBT095_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT095/SBT095_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT095/SBT095_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT095/SBT095_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT095/SBT095_visualization.png
# Successfully processed LS007
#
# Processing LS008 -> SBT096/SBT097
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS008/LS008_L_ES_MASK.nii
# Failed to process LS008
#
# Processing LS009 -> SBT096/SBT097
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS009/LS009_IDEALWater.nii
# Failed to process LS009
#
# Processing LS010 -> SBT096/SBT097
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS010/LS010_L_ES_MASK.nii
# Failed to process LS010
#
# Processing LS011 -> SBT096/SBT097
#
# Processing SBT096 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT096/SBT096_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT096/SBT096_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT096/SBT096_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT096/SBT096_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT096/SBT096_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT096/SBT096_visualization.png
#
# Processing SBT097 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT097/SBT097_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT097/SBT097_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT097/SBT097_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT097/SBT097_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT097/SBT097_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT097/SBT097_visualization.png
# Successfully processed LS011
#
# Processing LS012 -> SBT098/SBT099
#
# Processing SBT098 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT098/SBT098_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT098/SBT098_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT098/SBT098_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT098/SBT098_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT098/SBT098_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT098/SBT098_visualization.png
#
# Processing SBT099 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT099/SBT099_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT099/SBT099_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT099/SBT099_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT099/SBT099_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT099/SBT099_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT099/SBT099_visualization.png
# Successfully processed LS012
#
# Processing LS013 -> SBT100/SBT101
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS013/LS013_L_ES_MASK.nii
# Failed to process LS013
#
# Processing LS014 -> SBT100/SBT101
#
# Processing SBT100 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT100/SBT100_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT100/SBT100_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT100/SBT100_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT100/SBT100_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT100/SBT100_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT100/SBT100_visualization.png
#
# Processing SBT101 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT101/SBT101_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT101/SBT101_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT101/SBT101_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT101/SBT101_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT101/SBT101_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT101/SBT101_visualization.png
# Successfully processed LS014
#
# Processing LS015 -> SBT102/SBT103
#
# Processing SBT102 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT102/SBT102_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT102/SBT102_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT102/SBT102_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT102/SBT102_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT102/SBT102_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT102/SBT102_visualization.png
#
# Processing SBT103 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT103/SBT103_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT103/SBT103_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT103/SBT103_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT103/SBT103_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT103/SBT103_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT103/SBT103_visualization.png
# Successfully processed LS015
#
# Processing LS016 -> SBT104/SBT105
#
# Processing SBT104 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT104/SBT104_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT104/SBT104_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT104/SBT104_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT104/SBT104_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT104/SBT104_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT104/SBT104_visualization.png
#
# Processing SBT105 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT105/SBT105_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT105/SBT105_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT105/SBT105_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT105/SBT105_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT105/SBT105_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT105/SBT105_visualization.png
# Successfully processed LS016
#
# Processing LS017 -> SBT106/SBT107
#
# Processing SBT106 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT106/SBT106_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT106/SBT106_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT106/SBT106_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT106/SBT106_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT106/SBT106_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT106/SBT106_visualization.png
#
# Processing SBT107 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT107/SBT107_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT107/SBT107_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT107/SBT107_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT107/SBT107_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT107/SBT107_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT107/SBT107_visualization.png
# Successfully processed LS017
#
# Processing LS018 -> SBT108/SBT109
#
# Processing SBT108 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT108/SBT108_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT108/SBT108_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT108/SBT108_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT108/SBT108_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT108/SBT108_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT108/SBT108_visualization.png
#
# Processing SBT109 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT109/SBT109_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT109/SBT109_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT109/SBT109_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT109/SBT109_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT109/SBT109_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT109/SBT109_visualization.png
# Successfully processed LS018
#
# Processing LS019 -> SBT110/SBT111
#
# Processing SBT110 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT110/SBT110_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT110/SBT110_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT110/SBT110_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT110/SBT110_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT110/SBT110_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT110/SBT110_visualization.png
#
# Processing SBT111 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT111/SBT111_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT111/SBT111_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT111/SBT111_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT111/SBT111_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT111/SBT111_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT111/SBT111_visualization.png
# Successfully processed LS019
#
# Processing LS020 -> SBT112/SBT113
#
# Processing SBT112 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT112/SBT112_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT112/SBT112_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT112/SBT112_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT112/SBT112_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT112/SBT112_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT112/SBT112_visualization.png
#
# Processing SBT113 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT113/SBT113_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT113/SBT113_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT113/SBT113_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT113/SBT113_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT113/SBT113_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT113/SBT113_visualization.png
# Successfully processed LS020
#
# Processing LS021 -> SBT114/SBT115
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS021/LS021_L_ES_MASK.nii
# Failed to process LS021
#
# Processing LS022 -> SBT114/SBT115
#
# Processing SBT114 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT114/SBT114_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT114/SBT114_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT114/SBT114_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT114/SBT114_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT114/SBT114_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT114/SBT114_visualization.png
#
# Processing SBT115 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT115/SBT115_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT115/SBT115_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT115/SBT115_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT115/SBT115_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT115/SBT115_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT115/SBT115_visualization.png
# Successfully processed LS022
#
# Processing LS023 -> SBT116/SBT117
#
# Processing SBT116 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT116/SBT116_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT116/SBT116_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT116/SBT116_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT116/SBT116_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT116/SBT116_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT116/SBT116_visualization.png
#
# Processing SBT117 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT117/SBT117_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT117/SBT117_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT117/SBT117_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT117/SBT117_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT117/SBT117_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT117/SBT117_visualization.png
# Successfully processed LS023
#
# Processing LS024 -> SBT118/SBT119
#
# Processing SBT118 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT118/SBT118_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT118/SBT118_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT118/SBT118_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT118/SBT118_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT118/SBT118_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT118/SBT118_visualization.png
#
# Processing SBT119 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT119/SBT119_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT119/SBT119_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT119/SBT119_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT119/SBT119_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT119/SBT119_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT119/SBT119_visualization.png
# Successfully processed LS024
#
# Processing LS025 -> SBT120/SBT121
#
# Processing SBT120 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT120/SBT120_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT120/SBT120_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT120/SBT120_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT120/SBT120_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT120/SBT120_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT120/SBT120_visualization.png
#
# Processing SBT121 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT121/SBT121_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT121/SBT121_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT121/SBT121_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT121/SBT121_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT121/SBT121_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT121/SBT121_visualization.png
# Successfully processed LS025
#
# Processing LS026 -> SBT122/SBT123
#
# Processing SBT122 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT122/SBT122_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT122/SBT122_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT122/SBT122_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT122/SBT122_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT122/SBT122_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT122/SBT122_visualization.png
#
# Processing SBT123 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT123/SBT123_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT123/SBT123_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT123/SBT123_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT123/SBT123_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT123/SBT123_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT123/SBT123_visualization.png
# Successfully processed LS026
#
# Processing LS027 -> SBT124/SBT125
#
# Processing SBT124 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT124/SBT124_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT124/SBT124_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT124/SBT124_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT124/SBT124_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT124/SBT124_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT124/SBT124_visualization.png
#
# Processing SBT125 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT125/SBT125_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT125/SBT125_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT125/SBT125_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT125/SBT125_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT125/SBT125_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT125/SBT125_visualization.png
# Successfully processed LS027
#
# Processing LS028 -> SBT126/SBT127
#
# Processing SBT126 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT126/SBT126_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT126/SBT126_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT126/SBT126_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT126/SBT126_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT126/SBT126_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT126/SBT126_visualization.png
#
# Processing SBT127 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT127/SBT127_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT127/SBT127_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT127/SBT127_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT127/SBT127_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT127/SBT127_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT127/SBT127_visualization.png
# Successfully processed LS028
#
# Processing LS029 -> SBT128/SBT129
#
# Processing SBT128 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT128/SBT128_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT128/SBT128_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT128/SBT128_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT128/SBT128_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT128/SBT128_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT128/SBT128_visualization.png
#
# Processing SBT129 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT129/SBT129_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT129/SBT129_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT129/SBT129_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT129/SBT129_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT129/SBT129_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT129/SBT129_visualization.png
# Successfully processed LS029
#
# Processing LS030 -> SBT130/SBT131
#
# Processing SBT130 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT130/SBT130_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT130/SBT130_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT130/SBT130_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT130/SBT130_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT130/SBT130_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT130/SBT130_visualization.png
#
# Processing SBT131 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT131/SBT131_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT131/SBT131_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT131/SBT131_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT131/SBT131_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT131/SBT131_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT131/SBT131_visualization.png
# Successfully processed LS030
#
# Processing LS031 -> SBT132/SBT133
#
# Processing SBT132 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT132/SBT132_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT132/SBT132_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT132/SBT132_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT132/SBT132_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT132/SBT132_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT132/SBT132_visualization.png
#
# Processing SBT133 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT133/SBT133_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT133/SBT133_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT133/SBT133_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT133/SBT133_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT133/SBT133_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT133/SBT133_visualization.png
# Successfully processed LS031
#
# Processing LS046 -> SBT134/SBT135
#
# Processing SBT134 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT134/SBT134_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT134/SBT134_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT134/SBT134_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT134/SBT134_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT134/SBT134_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT134/SBT134_visualization.png
#
# Processing SBT135 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT135/SBT135_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT135/SBT135_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT135/SBT135_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT135/SBT135_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT135/SBT135_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT135/SBT135_visualization.png
# Successfully processed LS046
#
# Processing LS047 -> SBT136/SBT137
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS047/LS047_L_ES_MASK.nii
# Failed to process LS047
#
# Processing LS048 -> SBT136/SBT137
#
# Processing SBT136 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT136/SBT136_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT136/SBT136_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT136/SBT136_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT136/SBT136_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT136/SBT136_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT136/SBT136_visualization.png
#
# Processing SBT137 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT137/SBT137_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT137/SBT137_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT137/SBT137_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT137/SBT137_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT137/SBT137_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT137/SBT137_visualization.png
# Successfully processed LS048
#
# Processing LS049 -> SBT138/SBT139
#
# Processing SBT138 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT138/SBT138_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT138/SBT138_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT138/SBT138_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT138/SBT138_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT138/SBT138_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT138/SBT138_visualization.png
#
# Processing SBT139 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT139/SBT139_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT139/SBT139_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT139/SBT139_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT139/SBT139_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT139/SBT139_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT139/SBT139_visualization.png
# Successfully processed LS049
#
# Processing LS050 -> SBT140/SBT141
#
# Processing SBT140 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT140/SBT140_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT140/SBT140_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT140/SBT140_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT140/SBT140_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT140/SBT140_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT140/SBT140_visualization.png
#
# Processing SBT141 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT141/SBT141_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT141/SBT141_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT141/SBT141_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT141/SBT141_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT141/SBT141_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT141/SBT141_visualization.png
# Successfully processed LS050
#
# Processing LS051 -> SBT142/SBT143
#
# Processing SBT142 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT142/SBT142_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT142/SBT142_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT142/SBT142_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT142/SBT142_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT142/SBT142_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT142/SBT142_visualization.png
#
# Processing SBT143 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT143/SBT143_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT143/SBT143_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT143/SBT143_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT143/SBT143_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT143/SBT143_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT143/SBT143_visualization.png
# Successfully processed LS051
#
# Processing LS052 -> SBT144/SBT145
#
# Processing SBT144 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT144/SBT144_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT144/SBT144_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT144/SBT144_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT144/SBT144_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT144/SBT144_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT144/SBT144_visualization.png
#
# Processing SBT145 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT145/SBT145_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT145/SBT145_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT145/SBT145_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT145/SBT145_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT145/SBT145_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT145/SBT145_visualization.png
# Successfully processed LS052
#
# Processing LS053 -> SBT146/SBT147
#
# Processing SBT146 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT146/SBT146_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT146/SBT146_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT146/SBT146_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT146/SBT146_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT146/SBT146_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT146/SBT146_visualization.png
#
# Processing SBT147 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 186, 256)
# Fat data shape: (256, 186, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT147/SBT147_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT147/SBT147_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT147/SBT147_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT147/SBT147_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT147/SBT147_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT147/SBT147_visualization.png
# Successfully processed LS053
#
# Processing LS054 -> SBT148/SBT149
#
# Processing SBT148 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT148/SBT148_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT148/SBT148_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT148/SBT148_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT148/SBT148_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT148/SBT148_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT148/SBT148_visualization.png
#
# Processing SBT149 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT149/SBT149_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT149/SBT149_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT149/SBT149_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT149/SBT149_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT149/SBT149_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT149/SBT149_visualization.png
# Successfully processed LS054
#
# Processing LS055 -> SBT150/SBT151
# Warning: File not found: /Volumes/advent/research/MRI/Marines/Analysis2/LS055/LS055_L_ES_MASK.nii
# Failed to process LS055
#
# Processing LS057 -> SBT150/SBT151
#
# Processing SBT150 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT150/SBT150_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT150/SBT150_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT150/SBT150_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT150/SBT150_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT150/SBT150_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT150/SBT150_visualization.png
#
# Processing SBT151 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT151/SBT151_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT151/SBT151_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT151/SBT151_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT151/SBT151_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT151/SBT151_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT151/SBT151_visualization.png
# Successfully processed LS057
#
# Processing LS058 -> SBT152/SBT153
#
# Processing SBT152 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT152/SBT152_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT152/SBT152_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT152/SBT152_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT152/SBT152_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT152/SBT152_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT152/SBT152_visualization.png
#
# Processing SBT153 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 176, 256)
# Fat data shape: (256, 176, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT153/SBT153_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT153/SBT153_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT153/SBT153_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT153/SBT153_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT153/SBT153_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT153/SBT153_visualization.png
# Successfully processed LS058
#
# Processing LS059 -> SBT154/SBT155
#
# Processing SBT154 with OutPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved OutPhase image: /Volumes/advent/processed_data/SBT154/SBT154_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT154/SBT154_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT154/SBT154_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT154/SBT154_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT154/SBT154_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT154/SBT154_visualization.png
#
# Processing SBT155 with InPhase
# Image orientation: ('R', 'A', 'S')
# Image orientation: ('R', 'A', 'S')
# Water data shape: (256, 196, 256)
# Fat data shape: (256, 196, 256)
# Saved InPhase image: /Volumes/advent/processed_data/SBT155/SBT155_images.nii
#
# Processing mask: L_ES
# Saved mask to: /Volumes/advent/processed_data/SBT155/SBT155_L_ES_II.nii
#
# Processing mask: L_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT155/SBT155_L_Mult_II.nii
#
# Processing mask: R_ES
# Saved mask to: /Volumes/advent/processed_data/SBT155/SBT155_R_ES_II.nii
#
# Processing mask: R_Mult
# Saved mask to: /Volumes/advent/processed_data/SBT155/SBT155_R_Mult_II.nii
# Saved visualization to: /Volumes/advent/processed_data/SBT155/SBT155_visualization.png
# Successfully processed LS059
